# %%
#Import dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np
import tensorflow as tf

# Import findspark and initialize. 
import findspark
findspark.init()

# Start Spark session
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Asteroid DataFrame").getOrCreate()
spark.conf.set("spark.sql.execution.arrow.pyspark.enabled", "true")

# %%
# Read in data from S3 Buckets
from pyspark import SparkFiles
url = "https://s3.amazonaws.com/kat-project4-csv-site.click/dataset.csv"
spark.sparkContext.addFile(url)
spark_df = spark.read.csv(SparkFiles.get("dataset.csv"), sep=",", header=True)

#This takes about 3 minutes to load in.

# %%
# Show DataFrame
spark_df.show(10)
# Out:
# +--------+-------+--------------+----+-------+------+---+---+----+--------+------+--------------+--------+---------+---------+----------------+-------+------------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+--------------------+----------------+-----------------+----------------+-------+------------+----------+----------+----------+---------+---------+---------+---------+----------+----------+---------+---------+-----+------+
# |      id|  spkid|     full_name|pdes|   name|prefix|neo|pha|   H|diameter|albedo|diameter_sigma|orbit_id|    epoch|epoch_mjd|       epoch_cal|equinox|                 e|                a|                q|                i|               om|                w|               ma|               ad|                n|                  tp|          tp_cal|              per|           per_y|   moid|     moid_ld|   sigma_e|   sigma_a|   sigma_q|  sigma_i| sigma_om|  sigma_w| sigma_ma|  sigma_ad|   sigma_n| sigma_tp|sigma_per|class|   rms|
# +--------+-------+--------------+----+-------+------+---+---+----+--------+------+--------------+--------+---------+---------+----------------+-------+------------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+--------------------+----------------+-----------------+----------------+-------+------------+----------+----------+----------+---------+---------+---------+---------+----------+----------+---------+---------+-----+------+
# |a0000001|2000001|       1 Ceres|   1|  Ceres|  NULL|  N|  N| 3.4|   939.4| 0.090|           0.2|  JPL 47|2458600.5|    58600|20190427.0000000|  J2000| .0760090265983052|2.769165148633284|2.558683601195717|10.59406719506626|80.30553090445737|73.59769469844186|77.37209751948711|2.979646696070851|.2138852265918273|2458238.754129317955|20180430.2541293|1683.145702657688|4.60820178687936|1.59478| 620.6405326| 4.819E-12|1.0328E-11|1.9569E-11|4.6089E-9|6.1688E-8|6.6248E-8|7.8207E-9|1.1113E-11|1.1965E-12|3.7829E-8|9.4159E-9|  MBA|.43301|
# |a0000002|2000002|      2 Pallas|   2| Pallas|  NULL|  N|  N| 4.2|     545| 0.101|            18|  JPL 37|2459000.5|    59000|20200531.0000000|  J2000| .2299722588646258|2.773841434873298|2.135934854363191|34.83293159121413|173.0247412488342|310.2023924446679|144.9756754788195|3.411748015383405| .213344586343708|2458320.962365774508|20180721.4623658|1687.410991624711|4.61987951163507|1.23429| 480.3486393| 3.1934E-8| 4.0337E-9| 8.8322E-8|3.4694E-6|6.2724E-6|9.1282E-6|8.8591E-6| 4.9613E-9|4.6536E-10|4.0787E-5|3.6807E-6|  MBA|.35936|
# |a0000008|2000008|       8 Flora|   8|  Flora|  NULL|  N|  N| 6.5| 147.491| 0.226|         1.025| JPL 118|2459000.5|    59000|20200531.0000000|  J2000| .1558327925788342|2.201414664735624|1.858362069905874|5.889080654551788|110.8765239101335|285.4589150695398|315.3180129948375|2.544467259565375| .301752787794208|2459148.574810946354|20201026.0748109|  1193.0295744128|3.26633695937796| .87598| 340.9051366| 2.3644E-8| 2.3084E-9|  5.176E-8|3.2403E-6| 2.432E-5|2.6646E-5|1.2092E-5| 2.6681E-9|4.7462E-10|4.0187E-5|1.8765E-6|  MBA|.54186|
# |a0000009|2000009|       9 Metis|   9|  Metis|  NULL|  N|  N| 6.3|     190| 0.118|          NULL| JPL 116|2459000.5|    59000|20200531.0000000|  J2000| .1233002380520597|2.386189445512451|2.091971718843454|5.576493847075963| 68.9094592620561| 6.33732451976998|23.91220404136906|2.680407172181449|.2673909432494424|2458911.072124280732|20200302.5721243|1346.343281582895|3.68608701323175|1.10711| 430.8539987| 1.8414E-8| 3.0893E-9| 4.4258E-8|2.0074E-6| 2.417E-5|2.6008E-5|1.0366E-5| 3.4702E-9|5.1927E-10|3.8707E-5|2.6146E-6|  MBA|.44895|
# |a0000010|2000010|     10 Hygiea|  10| Hygiea|  NULL|  N|  N| 5.5|  407.12|0.0717|           6.8|  JPL 96|2459000.5|    59000|20200531.0000000|  J2000| .1121173200748112|3.142435383511873| 2.79011394980426|3.831786065854603|283.1984443208443|312.4129316933437| 222.850543374369|3.494756817219485|.1769312474587196|2459775.656783188508|20220715.1567832|2034.688644152542|5.57067390596179| 1.7803|  692.839351| 1.6346E-8| 6.9236E-9| 5.0952E-8|2.1734E-6|2.8552E-5|3.0237E-5|1.1246E-5| 7.6998E-9|5.8474E-10|6.4829E-5|6.7244E-6|  MBA|.53434|
# +--------+-------+--------------+----+-------+------+---+---+----+--------+------+--------------+--------+---------+---------+----------------+-------+------------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+--------------------+----------------+-----------------+----------------+-------+------------+----------+----------+----------+---------+---------+---------+---------+----------+----------+---------+---------+-----+------+
# only showing top 10 rows

# %%
#review all the column names
spark_df.columns
# Out:
# ['id',
#  'spkid',
#  'full_name',
#  'pdes',
#  'name',
#  'prefix',
#  'neo',
#  'pha',
#  'H',
#  'diameter',
#  'albedo',
#  'diameter_sigma',
#  'orbit_id',
#  'epoch',
#  'epoch_mjd',
#  'epoch_cal',
#  'equinox',
#  'e',
#  'a',
#  'q',
#  'i',
#  'om',
#  'w',
#  'ma',
#  'ad',
#  'n',
#  'tp',
#  'tp_cal',
#  'per',
#  'per_y',
#  'moid',
#  'moid_ld',
#  'sigma_e',
#  'sigma_a',
#  'sigma_q',
#  'sigma_i',
#  'sigma_om',
#  'sigma_w',
#  'sigma_ma',
#  'sigma_ad',
#  'sigma_n',
#  'sigma_tp',
#  'sigma_per',
#  'class',
#  'rms']

# %%
#Make a copy of the spark DF for later use. 
spark_df_copy = spark_df

#Drop unnecessary columns that don't determine the hazardousness of an asteroid
spark_df = spark_df.drop('spkid','pdes','full_name','name','prefix','orbit_id','equinox')

spark_df.show(10)
# Out:
# +--------+---+---+----+--------+------+--------------+---------+---------+----------------+------------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----
+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+--------------------+----------------+-----------------+----------------+-------+------------+----------+----------+----------+---------+---------+---------+---------+----------+----------+---------+---------+-----+------+
# only showing top 10 rows

# %%
#drop rows with null values
spark_df = spark_df.na.drop("any")

# %%
#Convert the spark df to pandas
df = spark_df.select("*").toPandas()

# %%
#display the pandas DF
df.head()
# Out:
#          id neo pha     H diameter  albedo diameter_sigma      epoch  \
# 0  a0000001   N   N   3.4    939.4   0.090            0.2  2458600.5
# 1  a0000002   N   N   4.2      545   0.101             18  2459000.5
# 2  a0000003   N   N  5.33  246.596   0.214         10.594  2459000.5
# 3  a0000004   N   N   3.0    525.4  0.4228            0.2  2458600.5
# 4  a0000005   N   N   6.9  106.699   0.274          3.140  2459000.5
#
#   epoch_mjd         epoch_cal  ...    sigma_i   sigma_om    sigma_w  \
# 0     58600  20190427.0000000  ...  4.6089E-9  6.1688E-8  6.6248E-8
# 1     59000  20200531.0000000  ...  3.4694E-6  6.2724E-6  9.1282E-6
# 2     59000  20200531.0000000  ...  3.2231E-6  1.6646E-5  1.7721E-5
# 3     58600  20190427.0000000  ...  2.1706E-7  3.8808E-7  1.7893E-7
# 4     59000  20200531.0000000  ...  2.7408E-6  2.8949E-5  2.9842E-5
#
#     sigma_ma    sigma_ad     sigma_n   sigma_tp  sigma_per class     rms
# 0  7.8207E-9  1.1113E-11  1.1965E-12  3.7829E-8  9.4159E-9   MBA  .43301
# 1  8.8591E-6   4.9613E-9  4.6536E-10  4.0787E-5  3.6807E-6   MBA  .35936
# 2  8.1104E-6   4.3639E-9  4.4134E-10  3.5288E-5  3.1072E-6   MBA  .33848
# 3  1.2068E-6   1.6486E-9  2.6125E-10  4.1037E-6  1.2749E-6   MBA   .3998
# 4  8.3038E-6    4.729E-9  5.5227E-10  3.4743E-5  3.4905E-6   MBA  .52191
#
# [5 rows x 38 columns]

# %%
#check number of entries in the dataset
len(df.index)
# Out:
# 131142

# %%
#set first column as the index
df = df.set_index('id')

# %%
#review datatypes
df.dtypes
# Out:
# neo               object
# pha               object
# H                 object
# diameter          object
# albedo            object
# diameter_sigma    object
# epoch             object
# epoch_mjd         object
# epoch_cal         object
# e                 object
# a                 object
# q                 object
# i                 object
# om                object
# w                 object
# ma                object
# ad                object
# n                 object
# tp                object
# tp_cal            object
# per               object
# per_y             object
# moid              object
# moid_ld           object
# sigma_e           object
# sigma_a           object
# sigma_q           object
# sigma_i           object
# sigma_om          object
# sigma_w           object
# sigma_ma          object
# sigma_ad          object
# sigma_n           object
# sigma_tp          object
# sigma_per         object
# class             object
# rms               object
# dtype: object

# %%
df.columns
# Out:
# Index(['neo', 'pha', 'H', 'diameter', 'albedo', 'diameter_sigma', 'epoch',
#        'epoch_mjd', 'epoch_cal', 'e', 'a', 'q', 'i', 'om', 'w', 'ma', 'ad',
#        'n', 'tp', 'tp_cal', 'per', 'per_y', 'moid', 'moid_ld', 'sigma_e',
#        'sigma_a', 'sigma_q', 'sigma_i', 'sigma_om', 'sigma_w', 'sigma_ma',
#        'sigma_ad', 'sigma_n', 'sigma_tp', 'sigma_per', 'class', 'rms'],
#       dtype='object')

# %%
#convert numerical columns to floats
df = df.astype({'H':"float", 'diameter': "float", 'albedo':"float", 'diameter_sigma':"float", 'epoch':"float",
       'epoch_mjd':"float", 'epoch_cal':"float", 'e':"float", 'a':"float", 'q':"float", 'i':"float", 'om':"float", 'w':"float", 'ma':"float", 'ad':"float",
       'n':"float", 'tp':"float", 'tp_cal':"float", 'per':"float", 'per_y':"float", 'moid':"float", 'moid_ld':"float", 'sigma_e':"float",
       'sigma_a':"float", 'sigma_q':"float", 'sigma_i':"float", 'sigma_om':"float", 'sigma_w':"float", 'sigma_ma':"float",
       'sigma_ad':"float", 'sigma_n':"float", 'sigma_tp':"float", 'sigma_per':"float", 'rms':"float"})

# %%
#Encode neo and pha N and Y values as 0s and 1s

# Create a function to encode the N and Y values
def encode(value):
    if value =="Y":
        return 1
    else:
        return 0

# Call the encode_function on the neo and pha columns
df["neo"] = df["neo"].apply(encode)
df["pha"] = df["pha"].apply(encode)

#Review the df
df.head()
# Out:
#           neo  pha     H  diameter  albedo  diameter_sigma      epoch  \
# id
# a0000001    0    0  3.40   939.400  0.0900           0.200  2458600.5
# a0000002    0    0  4.20   545.000  0.1010          18.000  2459000.5
# a0000003    0    0  5.33   246.596  0.2140          10.594  2459000.5
# a0000004    0    0  3.00   525.400  0.4228           0.200  2458600.5
# a0000005    0    0  6.90   106.699  0.2740           3.140  2459000.5
#
#           epoch_mjd   epoch_cal         e  ...       sigma_i      sigma_om  \
# id                                         ...
# a0000001    58600.0  20190427.0  0.076009  ...  4.608900e-09  6.168800e-08
# a0000002    59000.0  20200531.0  0.229972  ...  3.469400e-06  6.272400e-06
# a0000003    59000.0  20200531.0  0.256936  ...  3.223100e-06  1.664600e-05
# a0000004    58600.0  20190427.0  0.088721  ...  2.170600e-07  3.880800e-07
# a0000005    59000.0  20200531.0  0.190913  ...  2.740800e-06  2.894900e-05
#
#                sigma_w      sigma_ma      sigma_ad       sigma_n  \
# id
# a0000001  6.624800e-08  7.820700e-09  1.111300e-11  1.196500e-12
# a0000002  9.128200e-06  8.859100e-06  4.961300e-09  4.653600e-10
# a0000003  1.772100e-05  8.110400e-06  4.363900e-09  4.413400e-10
# a0000004  1.789300e-07  1.206800e-06  1.648600e-09  2.612500e-10
# a0000005  2.984200e-05  8.303800e-06  4.729000e-09  5.522700e-10
#
#               sigma_tp     sigma_per  class      rms
# id
# a0000001  3.782900e-08  9.415900e-09    MBA  0.43301
# a0000002  4.078700e-05  3.680700e-06    MBA  0.35936
# a0000003  3.528800e-05  3.107200e-06    MBA  0.33848
# a0000004  4.103700e-06  1.274900e-06    MBA  0.39980
# a0000005  3.474300e-05  3.490500e-06    MBA  0.52191
#
# [5 rows x 37 columns]

# %%
df['class'].unique()
# Out:
# array(['MBA', 'OMB', 'MCA', 'AMO', 'IMB', 'TJN', 'APO', 'ATE', 'CEN',
#        'AST', 'TNO'], dtype=object)

# %%
#Encode class values as numbers

# Create a function to encode the N and Y values
def encode2(value):
    if value =="MBA":
        return 0
    elif value =="OMB":
        return 1
    elif value =="MCA":
        return 2
    elif value =="AMO":
        return 3
    elif value =="IMB":
        return 4
    elif value =="TJN":
        return 5
    elif value =="APO":
        return 6
    elif value =="ATE":
        return 7
    elif value =="CEN":
        return 8
    elif value =="AST":
        return 9
    else:
        return 10

# Call the encode_function on the neo and pha columns
df["class"] = df["class"].apply(encode2)

#Review the df
df.head()
# Out:
#           neo  pha     H  diameter  albedo  diameter_sigma      epoch  \
# id
# a0000001    0    0  3.40   939.400  0.0900           0.200  2458600.5
# a0000002    0    0  4.20   545.000  0.1010          18.000  2459000.5
# a0000003    0    0  5.33   246.596  0.2140          10.594  2459000.5
# a0000004    0    0  3.00   525.400  0.4228           0.200  2458600.5
# a0000005    0    0  6.90   106.699  0.2740           3.140  2459000.5
#
#           epoch_mjd   epoch_cal         e  ...       sigma_i      sigma_om  \
# id                                         ...
# a0000001    58600.0  20190427.0  0.076009  ...  4.608900e-09  6.168800e-08
# a0000002    59000.0  20200531.0  0.229972  ...  3.469400e-06  6.272400e-06
# a0000003    59000.0  20200531.0  0.256936  ...  3.223100e-06  1.664600e-05
# a0000004    58600.0  20190427.0  0.088721  ...  2.170600e-07  3.880800e-07
# a0000005    59000.0  20200531.0  0.190913  ...  2.740800e-06  2.894900e-05
#
#                sigma_w      sigma_ma      sigma_ad       sigma_n  \
# id
# a0000001  6.624800e-08  7.820700e-09  1.111300e-11  1.196500e-12
# a0000002  9.128200e-06  8.859100e-06  4.961300e-09  4.653600e-10
# a0000003  1.772100e-05  8.110400e-06  4.363900e-09  4.413400e-10
# a0000004  1.789300e-07  1.206800e-06  1.648600e-09  2.612500e-10
# a0000005  2.984200e-05  8.303800e-06  4.729000e-09  5.522700e-10
#
#               sigma_tp     sigma_per  class      rms
# id
# a0000001  3.782900e-08  9.415900e-09      0  0.43301
# a0000002  4.078700e-05  3.680700e-06      0  0.35936
# a0000003  3.528800e-05  3.107200e-06      0  0.33848
# a0000004  4.103700e-06  1.274900e-06      0  0.39980
# a0000005  3.474300e-05  3.490500e-06      0  0.52191
#
# [5 rows x 37 columns]

# %%
# Remove target (pha) from features data
y = df.pha.values
X = df.drop(columns="pha").values


# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# First Model

# %%
# Define the deep learning model 
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=36, activation="relu", input_dim=36))
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train, y_train, epochs=10)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/10
# 3074/3074 [==============================] - 9s 3ms/step - loss: 5857.8701 - accuracy: 0.9945
# Epoch 2/10
# 3074/3074 [==============================] - 8s 3ms/step - loss: 2077.2605 - accuracy: 0.9970
# Epoch 3/10
# 3074/3074 [==============================] - 10s 3ms/step - loss: 1253.0131 - accuracy: 0.9973
# Epoch 4/10
# 3074/3074 [==============================] - 12s 4ms/step - loss: 932.8327 - accuracy: 0.9968
# Epoch 5/10
# 3074/3074 [==============================] - 10s 3ms/step - loss: 716.4424 - accuracy: 0.9970
# Epoch 6/10
# 3074/3074 [==============================] - 10s 3ms/step - loss: 364.1188 - accuracy: 0.9969
# Epoch 7/10
# 3074/3074 [==============================] - 10s 3ms/step - loss: 123.9867 - accuracy: 0.9969
# Epoch 8/10
# 3074/3074 [==============================] - 10s 3ms/step - loss: 12.4124 - accuracy: 0.9963
# Epoch 9/10
# 3074/3074 [==============================] - 10s 3ms/step - loss: 0.0116 - accuracy: 0.9986
# Epoch 10/10
# 3074/3074 [==============================] - 10s 3ms/step - loss: 0.0105 - accuracy: 0.9986
# 1025/1025 - 2s - loss: 0.0104 - accuracy: 0.9986 - 2s/epoch - 2ms/step
# Loss: 0.01043011900037527, Accuracy: 0.9986274838447571

# %% [markdown]
# Notes: Our first model was very accurate (99.86% accuracy). Future models will see if we can achieve the same accuaracy, with less data.

# %% [markdown]
# Optimization Attempt #1

# %%
#Copy the processed df
df_no_sigma = df.copy()

#remove all "simgma" columns from the DF
df_no_sigma = df_no_sigma.drop(columns=['diameter_sigma','sigma_e', 'sigma_a', 'sigma_q', 'sigma_i', 'sigma_om', 'sigma_w','sigma_ma', 'sigma_ad', 'sigma_n', 'sigma_tp', 'sigma_per'])
df_no_sigma.head()
# Out:
#           neo  pha     H  diameter  albedo      epoch  epoch_mjd   epoch_cal  \
# id
# a0000001    0    0  3.40   939.400  0.0900  2458600.5    58600.0  20190427.0
# a0000002    0    0  4.20   545.000  0.1010  2459000.5    59000.0  20200531.0
# a0000003    0    0  5.33   246.596  0.2140  2459000.5    59000.0  20200531.0
# a0000004    0    0  3.00   525.400  0.4228  2458600.5    58600.0  20190427.0
# a0000005    0    0  6.90   106.699  0.2740  2459000.5    59000.0  20200531.0
#
#                  e         a  ...        ad         n            tp  \
# id                            ...
# a0000001  0.076009  2.769165  ...  2.979647  0.213885  2.458239e+06
# a0000002  0.229972  2.773841  ...  3.411748  0.213345  2.458321e+06
# a0000003  0.256936  2.668285  ...  3.353865  0.226129  2.458446e+06
# a0000004  0.088721  2.361418  ...  2.570926  0.271609  2.458248e+06
# a0000005  0.190913  2.574037  ...  3.065455  0.238661  2.458926e+06
#
#                 tp_cal          per     per_y     moid     moid_ld  class  \
# id
# a0000001  2.018043e+07  1683.145703  4.608202  1.59478  620.640533      0
# a0000002  2.018072e+07  1687.410992  4.619880  1.23429  480.348639      0
# a0000003  2.018112e+07  1592.013769  4.358696  1.03429  402.514639      0
# a0000004  2.018051e+07  1325.432763  3.628837  1.13948  443.451432      0
# a0000005  2.020032e+07  1508.414421  4.129814  1.09575  426.433027      0
#
#               rms
# id
# a0000001  0.43301
# a0000002  0.35936
# a0000003  0.33848
# a0000004  0.39980
# a0000005  0.52191
#
# [5 rows x 25 columns]

# %%
# Remove target (pha) from features data
y = df_no_sigma.pha.values
X = df_no_sigma.drop(columns="pha").values


# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the deep learning model 
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=24, activation="relu", input_dim=24))
nn_model.add(tf.keras.layers.Dense(units=12, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train, y_train, epochs=10)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/10
# 3074/3074 [==============================] - 10s 2ms/step - loss: 6359.6904 - accuracy: 0.9957
# Epoch 2/10
# 3074/3074 [==============================] - 7s 2ms/step - loss: 3853.3975 - accuracy: 0.9970
# Epoch 3/10
# 3074/3074 [==============================] - 7s 2ms/step - loss: 2436.6074 - accuracy: 0.9970
# Epoch 4/10
# 3074/3074 [==============================] - 9s 3ms/step - loss: 1179.6735 - accuracy: 0.9970
# Epoch 5/10
# 3074/3074 [==============================] - 9s 3ms/step - loss: 588.6609 - accuracy: 0.9973
# Epoch 6/10
# 3074/3074 [==============================] - 9s 3ms/step - loss: 390.5569 - accuracy: 0.9970
# Epoch 7/10
# 3074/3074 [==============================] - 10s 3ms/step - loss: 239.9050 - accuracy: 0.9968
# Epoch 8/10
# 3074/3074 [==============================] - 11s 4ms/step - loss: 26.9086 - accuracy: 0.9975
# Epoch 9/10
# 3074/3074 [==============================] - 10s 3ms/step - loss: 0.2352 - accuracy: 0.9973
# Epoch 10/10
# 3074/3074 [==============================] - 10s 3ms/step - loss: 0.0142 - accuracy: 0.9986
# 1025/1025 - 2s - loss: 0.0129 - accuracy: 0.9986 - 2s/epoch - 2ms/step
# Loss: 0.012885482050478458, Accuracy: 0.9986274838447571

# %% [markdown]
# Notes: Sigma values in the data set don't impact the accuracy of training in determining if an asteroid is a potential hazard.

# %% [markdown]
# Optimization Attempt #2

# %%
#verifying that pha (potentialy hazardous asteroid) and neo (near earth object are not a total 1 to 1 relationship)
print(df['pha'].value_counts())

print(df['neo'].value_counts())
# Out:
# pha
# 0    130961
# 1       181
# Name: count, dtype: int64
# neo
# 0    130403
# 1       739
# Name: count, dtype: int64

# %%
df_no_sigma.columns
# Out:
# Index(['neo', 'pha', 'H', 'diameter', 'albedo', 'epoch', 'epoch_mjd',
#        'epoch_cal', 'e', 'a', 'q', 'i', 'om', 'w', 'ma', 'ad', 'n', 'tp',
#        'tp_cal', 'per', 'per_y', 'moid', 'moid_ld', 'class', 'rms'],
#       dtype='object')

# %%
#copy df with sigma coplumns removed
df3 = df_no_sigma.copy()

#remove additional columns of data
df3 = df3.drop(columns=['albedo', 'epoch', "epoch_mjd",	"epoch_cal", "e", "a", "q", "i", "om", "w", "ma", "ad", "n", "tp", "tp_cal",	"per", "per_y", "moid_ld"])

#display the new df
df3.head()
# Out:
#           neo  pha     H  diameter     moid  class      rms
# id
# a0000001    0    0  3.40   939.400  1.59478      0  0.43301
# a0000002    0    0  4.20   545.000  1.23429      0  0.35936
# a0000003    0    0  5.33   246.596  1.03429      0  0.33848
# a0000004    0    0  3.00   525.400  1.13948      0  0.39980
# a0000005    0    0  6.90   106.699  1.09575      0  0.52191

# %%
# Remove target (pha) from features data
y = df3.pha.values
X = df3.drop(columns="pha").values


# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the deep learning model 
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=6, activation="relu", input_dim=6))
nn_model.add(tf.keras.layers.Dense(units=3, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train, y_train, epochs=10)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/10
# 3074/3074 [==============================] - 8s 2ms/step - loss: 0.4037 - accuracy: 0.9348
# Epoch 2/10
# 3074/3074 [==============================] - 8s 3ms/step - loss: 0.0671 - accuracy: 0.9986
# Epoch 3/10
# 3074/3074 [==============================] - 8s 3ms/step - loss: 0.0193 - accuracy: 0.9986
# Epoch 4/10
# 3074/3074 [==============================] - 10s 3ms/step - loss: 0.0076 - accuracy: 0.9985
# Epoch 5/10
# 3074/3074 [==============================] - 10s 3ms/step - loss: 0.0046 - accuracy: 0.9985
# Epoch 6/10
# 3074/3074 [==============================] - 9s 3ms/step - loss: 0.0037 - accuracy: 0.9985
# Epoch 7/10
# 3074/3074 [==============================] - 10s 3ms/step - loss: 0.0033 - accuracy: 0.9987
# Epoch 8/10
# 3074/3074 [==============================] - 12s 4ms/step - loss: 0.0031 - accuracy: 0.9985
# Epoch 9/10
# 3074/3074 [==============================] - 10s 3ms/step - loss: 0.0029 - accuracy: 0.9986
# Epoch 10/10
# 3074/3074 [==============================] - 13s 4ms/step - loss: 0.0028 - accuracy: 0.9986
# 1025/1025 - 3s - loss: 0.0024 - accuracy: 0.9989 - 3s/epoch - 3ms/step
# Loss: 0.002432210138067603, Accuracy: 0.9989019632339478

# %% [markdown]
# Less information about the asteroid actually increased the accuracy of the model from 99.86% to 99.90%

# %% [markdown]
# Optimization Attempt #3

# %%
df4 = df3.copy()

df4= df4.drop(columns=['moid', 'class', 'rms']) 

df4.head()
# Out:
#           neo  pha     H  diameter
# id
# a0000001    0    0  3.40   939.400
# a0000002    0    0  4.20   545.000
# a0000003    0    0  5.33   246.596
# a0000004    0    0  3.00   525.400
# a0000005    0    0  6.90   106.699

# %%
# Remove target (pha) from features data
y = df4.pha.values
X = df4.drop(columns="pha").values


# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the deep learning model 
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=3, activation="relu", input_dim=3))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train, y_train, epochs=10)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/10
# 3074/3074 [==============================] - 15s 4ms/step - loss: 0.1188 - accuracy: 0.9669
# Epoch 2/10
# 3074/3074 [==============================] - 14s 5ms/step - loss: 0.0077 - accuracy: 0.9986
# Epoch 3/10
# 3074/3074 [==============================] - 13s 4ms/step - loss: 0.0049 - accuracy: 0.9986
# Epoch 4/10
# 3074/3074 [==============================] - 13s 4ms/step - loss: 0.0038 - accuracy: 0.9986
# Epoch 5/10
# 3074/3074 [==============================] - 13s 4ms/step - loss: 0.0036 - accuracy: 0.9985
# Epoch 6/10
# 3074/3074 [==============================] - 14s 5ms/step - loss: 0.0036 - accuracy: 0.9986
# Epoch 7/10
# 3074/3074 [==============================] - 14s 5ms/step - loss: 0.0035 - accuracy: 0.9985
# Epoch 8/10
# 3074/3074 [==============================] - 13s 4ms/step - loss: 0.0035 - accuracy: 0.9986
# Epoch 9/10
# 3074/3074 [==============================] - 18s 6ms/step - loss: 0.0035 - accuracy: 0.9986
# Epoch 10/10
# 3074/3074 [==============================] - 13s 4ms/step - loss: 0.0034 - accuracy: 0.9986
# 1025/1025 - 2s - loss: 0.0039 - accuracy: 0.9982 - 2s/epoch - 2ms/step
# Loss: 0.0038928284775465727, Accuracy: 0.9982004761695862

# %% [markdown]
# Accuracy went back down to our starting point. Removing moid, class, and rms did help determine which asteroids are hazardous and which are not.

# %% [markdown]
# Final Optimization Attempt
#
# Df3 gave us the most accurate Model. In this final attempt, we will recreate the df only using these columns and removing null values from these columns. This will ideally give us more data to train the model with.

# %%
#Take the copied spark DF and remove all but key columns from DF3

spark_df_copy = spark_df_copy.drop('spkid', 'full_name', 'pdes', 'name', 'prefix', 'albedo', 'diameter_sigma', 'orbit_id', 'epoch',
       'epoch_mjd', 'epoch_cal', 'equinox', 'e', 'a', 'q', 'i', 'om', 'w',
       'ma', 'ad', 'n', 'tp', 'tp_cal', 'per', 'per_y', 'moid_ld',
       'sigma_e', 'sigma_a', 'sigma_q', 'sigma_i', 'sigma_om', 'sigma_w',
       'sigma_ma', 'sigma_ad', 'sigma_n', 'sigma_tp', 'sigma_per')

# %%
#drop null values from the DF
df5 = spark_df_copy.na.drop("any")

# %%
#Convert to a pandas DF
df5 = df5.select("*").toPandas()

#show the DF
df5.head()
# Out:
#          id neo pha     H diameter     moid class     rms
# 0  a0000001   N   N   3.4    939.4  1.59478   MBA  .43301
# 1  a0000002   N   N   4.2      545  1.23429   MBA  .35936
# 2  a0000003   N   N  5.33  246.596  1.03429   MBA  .33848
# 3  a0000004   N   N   3.0    525.4  1.13948   MBA   .3998
# 4  a0000005   N   N   6.9  106.699  1.09575   MBA  .52191

# %%
#There are only a few 1000 more cases so this may not impact accuracy much
len(df5.index)
# Out:
# 132045

# %%
#set first column as the index
df5 = df5.set_index('id')

# %%
#convert numerical columns to floats
df5 = df5.astype({'H':"float", 'diameter': "float", 'moid':"float", 'rms':"float"})

# %%
#Encode neo and pha N and Y values as 0s and 1s

# Call the encode_function on the neo and pha columns
df5["neo"] = df5["neo"].apply(encode)
df5["pha"] = df5["pha"].apply(encode)

#Review the df
df5.head()
# Out:
#           neo  pha     H  diameter     moid class      rms
# id
# a0000001    0    0  3.40   939.400  1.59478   MBA  0.43301
# a0000002    0    0  4.20   545.000  1.23429   MBA  0.35936
# a0000003    0    0  5.33   246.596  1.03429   MBA  0.33848
# a0000004    0    0  3.00   525.400  1.13948   MBA  0.39980
# a0000005    0    0  6.90   106.699  1.09575   MBA  0.52191

# %%
#Encode class values as numbers

# Call the encode_function on the neo and pha columns
df5["class"] = df5["class"].apply(encode2)

#Review the df
df5.head()
# Out:
#           neo  pha     H  diameter     moid  class      rms
# id
# a0000001    0    0  3.40   939.400  1.59478      0  0.43301
# a0000002    0    0  4.20   545.000  1.23429      0  0.35936
# a0000003    0    0  5.33   246.596  1.03429      0  0.33848
# a0000004    0    0  3.00   525.400  1.13948      0  0.39980
# a0000005    0    0  6.90   106.699  1.09575      0  0.52191

# %%
# Remove target (pha) from features data
y = df5.pha.values
X = df5.drop(columns="pha").values


# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the deep learning model 
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=6, activation="relu", input_dim=6))
nn_model.add(tf.keras.layers.Dense(units=3, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train, y_train, epochs=10)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/10
# 3095/3095 [==============================] - 12s 4ms/step - loss: 0.0058 - accuracy: 0.9983
# Epoch 2/10
# 3095/3095 [==============================] - 13s 4ms/step - loss: 0.0032 - accuracy: 0.9983
# Epoch 3/10
# 3095/3095 [==============================] - 13s 4ms/step - loss: 0.0031 - accuracy: 0.9983
# Epoch 4/10
# 3095/3095 [==============================] - 14s 4ms/step - loss: 0.0029 - accuracy: 0.9983
# Epoch 5/10
# 3095/3095 [==============================] - 15s 5ms/step - loss: 0.0027 - accuracy: 0.9985
# Epoch 6/10
# 3095/3095 [==============================] - 16s 5ms/step - loss: 0.0025 - accuracy: 0.9988
# Epoch 7/10
# 3095/3095 [==============================] - 16s 5ms/step - loss: 0.0023 - accuracy: 0.9988
# Epoch 8/10
# 3095/3095 [==============================] - 16s 5ms/step - loss: 0.0022 - accuracy: 0.9991
# Epoch 9/10
# 3095/3095 [==============================] - 17s 5ms/step - loss: 0.0020 - accuracy: 0.9992
# Epoch 10/10
# 3095/3095 [==============================] - 16s 5ms/step - loss: 0.0019 - accuracy: 0.9993
# 1032/1032 - 3s - loss: 0.0020 - accuracy: 0.9992 - 3s/epoch - 3ms/step
# Loss: 0.0019521883223205805, Accuracy: 0.999212384223938

# %% [markdown]
# Model Accuracy is back up to 99.9% with the 6 features from df3 and slightly more data for training.
